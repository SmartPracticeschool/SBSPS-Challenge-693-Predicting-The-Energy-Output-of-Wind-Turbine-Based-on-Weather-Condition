# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhav-Somanath/SBSPS-Challenge-693-Predicting-The-Energy-Output-of-Wind-Turbine-Based-on-Weather-Condition/blob/master/Data_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from datetime import datetime, date, timedelta
import time
import types
import pandas as pd

df = pd.read_csv('/content/T1.csv')
df
# Out:
#               Date/Time  ...  Wind Direction (°)
# 0      01 01 2018 00:00  ...          259.994904
# 1      01 01 2018 00:10  ...          268.641113
# 2      01 01 2018 00:20  ...          272.564789
# 3      01 01 2018 00:30  ...          271.258087
# 4      01 01 2018 00:40  ...          265.674286
# ...                 ...  ...                 ...
# 50525  31 12 2018 23:10  ...           80.502724
# 50526  31 12 2018 23:20  ...           84.062599
# 50527  31 12 2018 23:30  ...           84.742500
# 50528  31 12 2018 23:40  ...           84.297913
# 50529  31 12 2018 23:50  ...           82.274620
#
# [50530 rows x 5 columns]

# %%
df.shape
# Out:
# (50530, 5)

# %%
world_weather_keys = ["151d22887cd746c8b30170119200305","a2a4c031e1174540953170617200305","3b8d0ddf95874ebc963171315200305","a7a8a673626349d6b2b171426200305",
                      "2c7acfdf3cd94dd6980171732200305","f2d087202dd74d3b8e9171937200305","dc721b5c73524d18bdc171944200305","a26775efe1e249b0a07172328200305",
                      "08ba377d157442f7b02172339200305","b32f31b4b4434128b88172618200305","54c5c4326ada4f189fc172631200305","c6f169f91683422f8ba172832200305",
                      "a39f242f81784b21808173201200305","e16a33c0b36040069aa173413200305","a39f242f81784b21808173201200305","01efbb6048bb48cc894173827200305",
                      "539ecc5092544eb087f173940200305","3d1b0704663e46e18f4174348200305","a339dad955e74b37a53174426200305","e2d4e57fb25f4535abf174810200305",
                      "e2fca3c1ea1a41c395f174907200305","f381fc760b034b70805175107200305","87ceb9281638401ca07175304200305","2c5dab9b79eb4daa9fb175507200305",
                      "e486c0fcdba54022b52150217200505","73160037869d421c95f150902200505","9c61f783fcd9467fb8e151028200505","25ac72b90a114c04963151054200505",
                      "40b9b6abd1ee4f3bab6151141200505","871cfe6fa20f440399f151257200505","36b3fc4cd1bc41aa9d7155722200505",
                      "f07f174181434b5e9e3155957200505","f280bed306334e0f9a2160217200505",
                      "6d401b23e9164970bc9160321200505","32309a1471524556b73160532200505","6af18246b3c748488f0160649200505",
                      "bd0cc1e7a4c14783bb1160745200505","65b031b57a9c41b5825161035200505","03ed5a8e69f5440087a161038200505","b17a228605634f84b51161207200505",
                      "f0b2df13be40426da7e161307200505","74b95c5a3847420d860161401200505","221fcd82d40f412fa77161510200505","d904fcc09e794699933161642200505",
                      "ca5283987239404aa31161717200505","cb7c0e83d493492081e161810200505","3b66bdc3b2ea4d2dabb161835200505","16f6c54894074e1bbdd162020200505",
                      "b6c7e4787cab459e801162135200505","a0d9bc141f2048dba26162253200505","fa5e3c18fbee4effbc0162451200505","4ee182c9c70842a088c162813200505",
                      "6dc633552a294225b6f162953200505","d7fbe569cc264b20b83163138200505","4b28dd6161354edeacc163136200505","72ae499526354e70a19163246200505",
                      "4b6a700637554250bad140000202004","760d2952fdb2440b9b6140246202004","febfd6293d25460591c75731202104",
                      "7361ac700d7c40ebb2675910202104","d384d3c0b88842b088483502202104","a72ea582edff4fb9a9d90545202104",
                      "954356550d2d4e31ab990731202104","12402144412b44a3bb290848202104","3494faf7c7304393bf391011202104"
                     ]

# %%
len(world_weather_keys)
# Out:
# 142

# %%
# !pip install wwo-hist
# Out:
# Collecting wwo-hist
#   Downloading https://files.pythonhosted.org/packages/5a/b4/19a4d6a0d131567cf4b2ffa3758710d867f7d7d3f0c6f94bd63fadf1d02a/wwo_hist-0.0.5-py3-none-any.whl
# Installing collected packages: wwo-hist
# Successfully installed wwo-hist-0.0.5

# %%
from wwo_hist import retrieve_hist_data

# %%
# frequency means no_of_hours  
frequency=1

final_data_new = []
# count to keep track of no_of_records collected
count = 0

# current_key_count to check the no_of_calls of current_key
current_key_count = 0

# key_track to keep track of key
key_track = 0
current_key = world_weather_keys[key_track]

# max number of requests from single key in one day
max_key_count = 500

# requests_time_out to keep track of number of times the request timed out 
requests_time_out = 0

# The latitude and longitude of wind farm of dataset in turkey, yalova
lat_long = ["40.6549,29.2842"]
for i in df.values:
    end_date = datetime.strptime(i[0], '%d %m %Y %H:%M')
    start_date = end_date
    one_row = []

    if current_key_count > max_key_count:
        key_track += 1
        current_key = world_weather_keys[key_track]
        current_key_count = 0
    try:
        hist_weather_data = retrieve_hist_data(current_key,
                                  lat_long,
                                  start_date,
                                  end_date,
                                  frequency,
                                  location_label = False,
                                  export_csv = False,
                                  store_df = True
                                  )
        current_key_count += 1
        
        records = hist_weather_data[0]
#         converting columns to numeric type 
        records = records[["maxtempC", "WindGustKmph", "DewPointC", "WindChillC", "humidity", "precipMM", "pressure"]].apply(pd.to_numeric)
        
        maxtempC = records["maxtempC"].values
        windGustKmph = records["WindGustKmph"].values
        DewPointC = records["DewPointC"].values
        windChillC = records["WindChillC"].values
        humidity = records["humidity"].values
        precipMM = records["precipMM"].values
        pressure = records["pressure"].values         
        
#         taking the average of every weather feature as data coming is from one hour before the date_time requested
        one_row.append([ end_date,  sum(maxtempC) / len(maxtempC), sum(windGustKmph) / len(windGustKmph), 
                         sum(DewPointC) / len(DewPointC), sum(windChillC) / len(windChillC),
                         sum(humidity) / len(humidity), sum(precipMM) / len(precipMM), sum(pressure) / len(pressure)])

    except HTTPError:
        requests_time_out += 1

    final_data_new.extend(one_row)  

    count += 1

    if count % 1000 == 0:
        print("Count:{}, Len(Final data):{}, key track:{}".format(count, len(final_data_new), key_track))
# Out:
# Streaming output truncated to the last 5000 lines.
# Time elapsed (hh:mm:ss.ms) 0:00:00.088484
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.091018
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.086619
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.085317
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.046636
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.052865
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.092828
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.090344
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.060469
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.086722
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.085255
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.095767
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.090235
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.089893
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.053666
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.086966
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.094467
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.087989
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.091119
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.087679
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.093436
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.050659
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.046502
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.086853
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.088015
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.092913
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00.048968
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-19 to 2018-09-19
# Time elapsed (hh:mm:ss.ms) 0:00:00
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.058058
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086743
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.091744
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088775
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086034
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.050535
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086669
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086974
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086992
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.049153
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088043
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.091053
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.090598
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.092959
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.095953
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.090521
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.396057
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088003
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088607
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086600
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.093666
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086412
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086061
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.045507
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.091537
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086053
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088364
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086472
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.092027
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086776
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.095075
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086643
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086643
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.083281
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.084029
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086619
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086937
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.085306
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.087429
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.047947
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.090128
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.047680
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.085194
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.047742
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088816
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.095105
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.090566
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088706
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.049772
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.052674
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.049859
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088965
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.087903
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.087102
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.085971
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.090059
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.087764
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.093394
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.054334
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.088394
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.092663
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086357
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.049384
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.050936
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.087690
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.050722
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.084929
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.086433
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.051994
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.091810
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.062944
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.084980
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# Time elapsed (hh:mm:ss.ms) 0:00:00.050178
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-09-24 to 2018-09-24
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-a1416d373c17> in <module>()
#      39                                   export_csv = False,
# ---> 40                                   store_df = True
#      41                                   )
#
# /usr/local/lib/python3.6/dist-packages/wwo_hist/__init__.py in retrieve_hist_data(api_key, location_list, start_date, end_date, frequency, location_label, export_csv, store_df, response_cache_path)
#     118         print('\n\nRetrieving weather data for ' + location + '\n\n')
# --> 119         df_this_city = retrieve_this_location(api_key, location, start_date, end_date, frequency, response_cache_path)
#     120
#
# /usr/local/lib/python3.6/dist-packages/wwo_hist/__init__.py in retrieve_this_location(api_key, location, start_date, end_date, frequency, response_cache_path)
#      94                 frequency)
# ---> 95             json_page = urllib.request.urlopen(url_page, timeout=10)
#      96             json_data = json.loads(json_page.read().decode())
#
# /usr/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#
# /usr/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#
# /usr/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#
# /usr/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#
# /usr/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#
# /usr/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#
# HTTPError: HTTP Error 401: Unauthorized
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a1416d373c17> in <module>()
#      59                          sum(humidity) / len(humidity), sum(precipMM) / len(precipMM), sum(pressure) / len(pressure)])
#      60
# ---> 61     except HTTPError:
#      62         requests_time_out += 1
#      63
#
# NameError: name 'HTTPError' is not defined

# %%
len(final_data_new)
# Out:
# 979

# %%
data_integrated = np.concatenate( (df.values, np.array(final_data_new)), axis = 1 )

# %%
df = pd.DataFrame( data_integrated, columns = ["DateTime", "LV ActivePower", "Wind Speed (m/s)", "Theoretical_Power_Curve (KWh)", "Wind Direction",
                                         "end_date",  "maxtempC", "windGustKmph", "DewPointC", "windChillC", "humidity", "precipMM", "pressure"] )

# %%
df.drop(df.columns[0], axis=1, inplace = True)

# %%
df["end_date"] = df["end_date"].apply(pd.to_datetime)

# %%
lVActivePower = df["LV ActivePower"]
df.drop("LV ActivePower", axis = 1, inplace = True)

# %%
df["LV ActivePower"] = lVActivePower
df.head()

# %%
from project_lib import Project
project = Project(project_id='<ProjectID>', project_access_token='<ProjectAccessToken>')
pc = project.project_context

# %%
from project_lib import Project
project = Project(pc,'<ProjectID>','<ProjectAccessToken>')

project.save_data(file_name = "integrated_data.csv",data = df.to_csv(index=False))
